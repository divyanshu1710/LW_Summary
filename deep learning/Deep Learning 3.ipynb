# %%
#Multiclass Classification through deep learning:
#all real life problem is based on Multiclass problem
#two types of problem in ml : regression and classification

# %%
import pandas as pd
ds=pd.read_csv("wine.csv")
ds
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# ...

# %%
y= ds["Wine"]

# %%
import seaborn as sns

# %%
sns.scatterplot(data= ds, x="Wine",y=y)
# Out:
# <AxesSubplot:xlabel='Wine', ylabel='Wine'>

# %%
y            #here y is multiclass so thatswhy it is not showing in above graph.
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Wine, Length: 178, dtype: int64

# %%
pd.get_dummies(y)
# Out:
#      1  2  3
# 0    1  0  0
# 1    1  0  0
# 2    1  0  0
# 3    1  0  0
# 4    1  0  0
# ..  .. .. ..
# 173  0  0  1
# 174  0  0  1
# 175  0  0  1
# 176  0  0  1
# 177  0  0  1
#
# [178 rows x 3 columns]

# %%
ds.columns
# Out:
# Index(['Wine', 'Alcohol', 'Malic.acid', 'Ash', 'Acl', 'Mg', 'Phenols',
#        'Flavanoids', 'Nonflavanoid.phenols', 'Proanth', 'Color.int', 'Hue',
#        'OD', 'Proline'],
#       dtype='object')

# %%
X= ds.drop("Wine", axis=1)

# %%
X
# Out:
#      Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0      14.23        1.71  2.43  15.6  127     2.80        3.06
# 1      13.20        1.78  2.14  11.2  100     2.65        2.76
# 2      13.16        2.36  2.67  18.6  101     2.80        3.24
# 3      14.37        1.95  2.50  16.8  113     3.85        3.49
# 4      13.24        2.59  2.87  21.0  118     2.80        2.69
# ..       ...         ...   ...   ...  ...      ...         ...
# 173    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# 1                    0.26     1.28       4.38  1.05  3.40     1050
# ...

# %%
# !pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.13.0-cp39-cp39-win_amd64.whl (1.9 kB)
# ...
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\91800\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\91800\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "C:\Users\91800\anaconda3\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\91800\anaconda3\lib\http\client.py", line 463, in read
#     n = self.readinto(b)
#   File "C:\Users\91800\anaconda3\lib\http\client.py", line 507, in readinto
#     n = self.fp.readinto(b)
#   File "C:\Users\91800\anaconda3\lib\socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\91800\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
# ...

# %%
from keras import Sequential
model.Sequential()
from keras.layers import Dense
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 from keras import Sequential
#       2 model.Sequential()
#       3 from keras.layers import Dense
#
# File ~\anaconda3\lib\site-packages\keras\__init__.py:3, in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras import __internal__
#       4 from keras import activations
#       5 from keras import applications
#
# File ~\anaconda3\lib\site-packages\keras\__internal__\__init__.py:3, in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.__internal__ import backend
#       4 from keras.__internal__ import layers
#       5 from keras.__internal__ import losses
#
# File ~\anaconda3\lib\site-packages\keras\__internal__\backend\__init__.py:3, in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ...

# %%
pip install tensorflow
