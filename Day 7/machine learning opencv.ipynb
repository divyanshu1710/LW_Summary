# %%
#computervision= computer vision is a subpart or alias of aartificial intelligence which is used to provide eyes to the sys.
#provide vision to the computer machines to perform and adapt various tasks.
#5 senses are there which is used by human whereas computer cannot taste or smell but it can use vision and touch.
#fist step to CV is image processing .
#use cases= attendance monitoring, identification, OCR, challan system etc.
#task= create an image by only using numpy array.

# %% [markdown]
# # Image Processing

# %%
import cv2

# %%
camvid= cv2.VideoCapture(0)  #this command will run a process which connect you to your system webcam.

# %%
status, pic = camvid.read()  #for clicking the photo or video

# %%
status #photo click hui yaa nhi
# Out:
# True

# %%
#command to store image in hard disk
cv2.imwrite("div.png", pic)
# Out:
# True

# %%
#command to show thee image on screen
#imshow will not work properly untill it is used with run and wait moule ,if not the code will crash..
#in dono ko same cell me hi likhna he kyuki vo ek cell ko ek jaise hi treat krta he.
cv2.imshow("my pic", pic)
cv2.waitKey(5000)  #it is in millisecond 5000 millisecond == 5 sec
#band krne ke liye bhi ek command likhni pdegi nhi to system band nhi krne dega image ko
cv2.destroyAllWindows()

# %%
#all the digital images are not just images but they are in the form of Array in hard disk where RGB color are 
#composed in the array.an image is generated by displaying pixel by pixel according to that array.
pic
# Out:
# array([[[138, 119, 161],
#         [138, 117, 167],
#         [138, 116, 172],
#         ...,
#         [ 52,  84, 110],
#         [ 46,  85, 104],
#         [ 43,  81, 101]],
#
#        [[139, 119, 164],
#         [139, 118, 168],
#         [137, 116, 171],
#         ...,
#         [ 56,  87, 111],
#         [ 49,  86, 105],
#         [ 45,  82, 102]],
#
#        [[138, 117, 167],
#         [138, 118, 169],
#         [135, 115, 168],
#         ...,
#         [ 61,  88, 111],
#         [ 55,  89, 109],
#         [ 54,  88, 108]],
#
#        ...,
#
#        [[ 55,  51, 132],
#         [ 57,  52, 133],
#         [ 55,  51, 132],
#         ...,
#         [141, 137, 137],
#         [150, 146, 147],
#         [167, 163, 163]],
#
#        [[ 57,  58, 140],
#         [ 54,  55, 136],
#         [ 50,  51, 133],
#         ...,
#         [136, 128, 129],
#         [147, 139, 140],
#         [155, 147, 148]],
#
#        [[ 56,  60, 141],
#         [ 50,  54, 135],
#         [ 48,  52, 133],
# ...

# %%
#shape of image
pic.shape
# Out:
# (480, 640, 3)

# %%
#dimension of image
pic.ndim
# Out:
# 3

# %%
type(pic)
# Out:
# numpy.ndarray

# %%
#to update our image colors by traversing a pixel
pic[100] = [0,255,0]`
# Out:
#   Input In [12]
#     pic[100] = [0,255,0]`
#                         ^
# SyntaxError: invalid syntax

# %%
crop =pic[100:350,300:500]

# %%
cv2.imshow("my pic", crop)
cv2.waitKey(5000)  
cv2.destroyAllWindows()

# %%
invert=pic[::-1]

# %%
cv2.imshow("my pic", invert)
cv2.waitKey(5000)  
cv2.destroyAllWindows()

# %%
#translocate one atrribute of image to diffetent location
pic[0:250,0:200]=pic[100:350,300:500]

# %%
cv2.imshow("my pic", invert)
cv2.waitKey(5000)  
cv2.destroyAllWindows()

# %%
import cv2
camvid= cv2.VideoCapture(0)

# %%
#ther is no way to stop this program so we have to modify with it by using brek function in if statement
while True:
    status, pic = camvid.read()
    cv2.imshow("my pic", pic)
    if cv2.waitKey(1) ==27:
        break

cv2.destroyAllWindows()
